# %% [markdown]
# # Theory Questions:
#
# 1. What is Object-Oriented programming?
#
#  Ans- Object-oriented programming (OOP) is a programming paradigm based on the concept of &quot;objects,&quot;
#  which can contain data and code: data in the form of fields (often known as attributes or properties), and code in the form of procedures (often known as methods). In OOP, computer programs are designed by making them out of objects that interact with one another.
#
# 2. What is a class in OOPS?
#
#  Ans- In Object-Oriented Programming (OOP) with Python, a class is like a blueprint or a template for creating objects. A class defines the structure and behavior that objects created from it will have. It provides a way to structure our code by grouping related data (attributes) and behavior (methods)into reusable units (objects). They are essential for modeling real-world entities and creating complex software systems.
# 3. What is an object in OOP?
#
#  Ans- In Object-Oriented Programming (OOP), an object is a specific instance of a class. Think of a class as a blueprint or template, and an object as a concrete thing built from that blueprint. An object is created from a class. The class defines the general structure and behavior, while the object represents a particular thing with its own specific data. In essence, objects are the core components of an object-oriented program. They allow you to represent real-world entities and their interactions in a structured and organized way.
#
# 4. What is the difference between abstraction and encapsulation?
#
#  Ans- Abstraction and encapsulation are both fundamental concepts in object-oriented programming, but they differ in purpose. Abstraction is the concept of hiding complex implementation details and showing only the necessary features of an object, allowing the user to interact with it without needing to understand its inner workings. It focuses on what an object does. On the other hand, encapsulation involves bundling data and methods that operate on the data into a single unit (class), and restricting access to some of the object's components, typically through private attributes and public methods. It focuses on how data is protected and accessed. In essence, abstraction hides complexity, while encapsulation protects data integrity.
#
# 5. What are dunder methods in Python?
#
#  Ans- Dunder methods (short for "double underscore" methods) in Python are special methods that have double underscores before and after their name, such as __init__, __str__, and __add__. These methods are used to implement basic operations or customize behavior for objects in a class. For example, __init__ is called when an object is created, __str__ defines how an object is represented as a string, and __add__ allows you to define custom behavior for the + operator. Dunder methods allow you to make your class behave like built-in types by defining how they should interact with common operations.
#
# 6. Explain the concept of inheritance in OOPS.
#
#  Ans: Inheritance is a fundamental concept in Object-Oriented Programming (OOP) that allows us to create new classes (called derived classes or subclasses) based on existing classes (called base classes or superclasses). Think of it like a family tree: the derived class inherits characteristics and behaviors from its parent (the base class), but can also have its own unique traits.
#  Inheritance is a powerful tool in OOP that helps you create well-structured, maintainable, and extensible code. It&#39;s a key concept for building complex software systems.
#
# 7. What is polymorphism in OOP?
#
#  Ans: Polymorphism, meaning &quot;many forms,&quot; is a core concept in Object-Oriented Programming (OOP) that allows objects of different classes to respond to the same method call in their own specific ways.
#  Key Benefits of Polymorphism:
#
#  i) Code Reusability: You can write code that works with objects of different classes without having to write separate code for each class.
#
#  ii) Flexibility: It makes your code more adaptable to changes. You can add new classes without affecting existing code.
#
#  iii)  Maintainability: Polymorphism can make your code easier to maintain because changes to one class are less likely to affect other parts of the system.
#
#  Polymorphism is a powerful tool that allows you to write more flexible, reusable, and maintainable code in object-oriented programming. It&#39;s a key concept for designing robust and extensible software systems.
#
# 8. How is encapsulation achieved in Python?
#
#  Ans- Encapsulation in Python is achieved by restricting access to an object's internal state and protecting its data through the use of private or protected attributes and methods. This is done by prefixing variables and methods with a double underscore (e.g., __variable), making them private and preventing direct access from outside the class. To interact with private attributes, public methods like getters and setters are provided. This ensures that the internal implementation details are hidden, promoting data integrity and controlling how data is accessed or modified.
#
# 9. What is a constructor in Python?
#
#  Ans: In Python, a constructor is a special method within a class that is automatically called when you create a new object (instance) of that class. Its primary purpose is to initialize the object&#39;s attributes (data). The constructor&#39;s name is always __init__ (double underscores on either side).
#  Key Points about Constructors:
#
#  i) They are automatically called during object creation.
#
#  ii) They initialize the object&#39;s attributes.
#
#  iii)  They use the self parameter to refer to the current object.
#
#  iv)They are essential for setting up the initial state of an object.
# The constructor is a fundamental part of object-oriented programming in Python. It ensures that objects are properly initialized when they are created, making your code more robust and predictable.
#
# 10. What are class and static methods in Python?
#
#  Ans: In Python, class methods and static methods are two types of methods that are defined within a class but behave differently.
#
#  Class Method: A class method is bound to the class and not the instance. It takes a reference to the class (cls) as its first parameter, rather than a reference to the instance (self). Class methods are used for operations that are related to the class, rather than an instance of the class. They are defined using the @classmethod decorator.
#
#  Static Method: A static method, unlike the class method, does not take a reference to the instance or class as its first parameter. It behaves like a regular function but resides within the class's namespace. Static methods are defined using the @staticmethod decorator and are used when the method does not need to access or modify class or instance data.
#
# 11. What is method overloading in Python?
#
#  Ans: Method overloading is a feature in some object-oriented programming languages that allows you
# to define multiple methods within a class that have the same name but different parameters (either in number or type). When you call the method, the compiler or interpreter determines which version of the method to execute based on the arguments you provide. Python, due to its dynamic typing, does not directly support method overloading in the same way as
# languages like Java or C++. If you define two methods with the same name in a Python class, the second
# definition will simply override the first one.
#
# 12. What is method overriding in OOPS?
#
#  Ans: Method overriding is a key concept in object-oriented programming (OOP) that occurs when a derived class (subclass) provides a specific implementation for a method that is already defined in its base class (superclass). It allows a subclass to customize or extend the behavior inherited from its superclass.
#  Method overriding is a powerful tool in OOP that enables you to create flexible and extensible class hierarchies. It&#39;s a key concept for building complex software systems where you need to model different types of objects with varying behaviors.
#
# 13. What is the property decorator in Python?
#
#  Ans: The @property decorator in Python is a built-in function that allows you to define methods in a class that can be accessed like attributes. It&#39;s a way to create &quot;managed attributes&quot; or &quot;computed properties.&quot; Think of it as a way to add getters, setters, and deleters to your class attributes, but with a cleaner syntax. Key Benefits of @property:
#
#  i) Controlled Access: You can control how attributes are accessed and modified.
#
#  ii) Data Validation: You can add validation logic to ensure data integrity.
#
#  iii) Computed Properties: You can create properties that are calculated dynamically.
#
#  iv) Cleaner Syntax: It provides a more Pythonic way to work with managed attributes.
#
#  The @property decorator is a powerful tool for creating well-designed classes in Python. It helps you encapsulate data, control access, and make your code more readable and maintainable.
#
# 14. Why is polymorphism important in OOPS?
#
#  Ans- Polymorphism is important in OOP because it enhances code reusability, flexibility, and maintainability. It allows different classes to use the same interface, making code simpler and more scalable. It supports encapsulation and abstraction, reduces dependency between components (loose coupling), and makes it easier to extend and modify systems.
#
# 15. What is an abstract class in Python?
#
#  Ans- An abstract class in Python is a blueprint for other classes and cannot be instantiated. It is defined using the ABC module and contains at least one @abstractmethod, which must be implemented by its subclasses.
#
# 16. What are the advantages of OOP?
#
#  Ans- Advantages of OOP:
#
#   i. Encapsulation – Protects data by restricting direct access.
#
#   ii. Reusability – Code can be reused using inheritance.
#
#   iii. Polymorphism – Allows flexibility with a common interface.
#
#   iv. Abstraction – Hides complex implementation details.
#
#   v. Modularity – Organizes code into objects for better structure.
#
#   vi. Scalability & Maintainability – Easier to extend and update.
#
# 17. What is the difference between a class variable and an instance variable?
#
#   Ans-  A class variable is shared across all instances of a class, while an instance variable is unique to each instance. Class variables are defined inside the class but outside methods, whereas instance variables are defined within methods using self. Class variables have a common value for all objects unless explicitly changed, whereas instance variables store data specific to each object.
#
# 18.  What is multiple inheritance in Python?
#
#  Ans-  Multiple inheritance in Python allows a class to inherit from more than one parent class. This enables a child class to access attributes and methods from multiple base classes. It helps in code reusability but can lead to complexity, especially with the diamond problem (resolved using the Method Resolution Order - MRO).
#
# 19.  Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python.
#
#  Ans- The __str__ and __repr__ methods in Python serve different purposes for representing an object as a string:
#
#  __str__: Used for a human-readable string representation of an object. It is called by print() and str().
#
#  __repr__: Used for a developer-friendly or official string representation. It is called by repr() and aims to provide a more precise, unambiguous string that can ideally recreate the object.
#
# 20. What is the significance of the ‘super()’ function in Python?
#
#  Ans- The super() function in Python is used to call methods from a parent class in a child class. It helps in accessing inherited methods that have been overridden in the subclass, allowing for better method resolution and supporting multiple inheritance.
#
#  Significance:
#
#  i) Access Parent Class Methods – Calls a method from the parent class without explicitly naming it.
#
#  ii) Avoids Redundant Code – Promotes reusability by using the parent class’s method.
#
#  iii) Supports Multiple Inheritance – Helps in method resolution when multiple inheritance is used.
#
# 21. What is the significance of the __del__ method in Python?
#
#  Ans- The __del__ method in Python is a destructor method called when an object is about to be destroyed or garbage collected. It allows for cleanup operations like releasing resources (e.g., closing files or network connections) before the object is removed from memory.
#
#  Significance:
#
#  i) Resource Cleanup – Used to free resources held by the object.
#
#  ii) Automatic Cleanup – Called automatically when an object is deleted or goes out of scope.
#
#  iii) Garbage Collection – Helps in cases where explicit deletion or resource deallocation is needed.
#
# 22. What is the difference between @staticmethod and @classmethod in Python?
#
#  Ans- The difference between @staticmethod and @classmethod lies in how they interact with the class. The @staticmethod does not take the instance (self) or the class (cls) as the first argument, making it independent of both. It is used when the method doesn't need access to the class or instance, and it can be called on either the class or an instance. On the other hand, the @classmethod takes the class (cls) as its first argument, allowing it to modify class-level variables or call other class methods. It is used when the method requires access to the class itself. For example, Example.static_method() and Example.class_method() can be called on the class directly, but static_method doesn't interact with the class or instance, while class_method can access class attributes.
#
# 23. How does polymorphism work in Python with inheritance?
#
#   Ans- In Python, polymorphism allows different classes to define methods with the same name, but each method can behave differently depending on the class. When polymorphism works with inheritance, a subclass can override a method from the parent class, and the correct method is called based on the object's class, not the reference type.
#
#   How it works:
#
#   i) Method Overriding: A subclass provides its own implementation of a method that is already defined in the parent class.
#
#   ii) Dynamic Method Resolution: Python calls the method of the subclass even if the reference is of the parent class type (thanks to dynamic typing).
#
# 24. What is method chaining in Python OOPS?
#
#  Ans- Method chaining in Python is the practice of calling multiple methods on the same object in a single statement. This is possible when each method returns the object itself (self), allowing the next method to be called on the same instance.
#
# 25. What is the purpose of the __call__ method in Python?
#
#  Ans- The __call__ method in Python allows an object to be called like a function. It is used to define behavior for when an instance of a class is called directly, enabling objects to be used as callable entities. It has two purpose-
#
#   i) Allows objects to behave like functions.
#
#  ii) Enables dynamic behavior and flexibility in the code.

# %% [markdown]
# # Practical Questions:

# %%
# Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!"

class Animal:
    def speak(self):
        print("Animal speaks")

class Dog(Animal):
    def speak(self):
        print("Bark!")


animal = Animal()
animal.speak()

dog = Dog()
dog.speak()

# %%
# Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.

from abc import ABC, abstractmethod
import math


class Shape(ABC):
    @abstractmethod
    def area(self):
        pass


class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

circle = Circle(5)
rectangle = Rectangle(4, 6)


print("Circle Area:", circle.area())
print("Rectangle Area:", rectangle.area())

# %%
#  Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.

 class Vehicle:
    def __init__(self, type):
        self.type = type

    def show_type(self):
        print(f"Vehicle type: {self.type}")


class Car(Vehicle):
    def __init__(self, type, brand):
        super().__init__(type)
        self.brand = brand

    def show_brand(self):
        print(f"Car brand: {self.brand}")


class ElectricCar(Car):
    def __init__(self, type, brand, battery):
        super().__init__(type, brand)
        self.battery = battery

    def show_battery(self):
        print(f"Battery capacity: {self.battery} kWh")


tesla = ElectricCar("Four-wheeler", "Tesla", 75)

tesla.show_type()
tesla.show_brand()
tesla.show_battery()

# %%
#   Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.

class Vehicle:
    def __init__(self, type):
        self.type = type

    def show_type(self):
        print(f"Vehicle type: {self.type}")


class Car(Vehicle):
    def __init__(self, type, brand):
        super().__init__(type)
        self.brand = brand

    def show_brand(self):
        print(f"Car brand: {self.brand}")


class ElectricCar(Car):
    def __init__(self, type, brand, battery):
        super().__init__(type, brand)
        self.battery = battery

    def show_battery(self):
        print(f"Battery capacity: {self.battery} kWh")


tesla = ElectricCar("Four-wheeler", "Tesla", 75)

tesla.show_type()
tesla.show_brand()
tesla.show_battery()

# %%
# Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance.

class BankAccount:
    def __init__(self, initial_balance=0):
        self.__balance = initial_balance

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: ${amount}")
        else:
            print("Deposit amount must be positive.")

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrawn: ${amount}")
        else:
            print("Insufficient balance or invalid amount.")

    def check_balance(self):
        print(f"Current Balance: ${self.__balance}")


account = BankAccount(100)


account.deposit(50)
account.withdraw(30)
account.check_balance()

# %%
# Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().

class Instrument:
    def play(self):
        print("Playing an instrument")


class Guitar(Instrument):
    def play(self):
        print("Playing the guitar: Strumming strings")


class Piano(Instrument):
    def play(self):
        print("Playing the piano: Pressing keys")


def play_instrument(instrument):
    instrument.play()


guitar = Guitar()
piano = Piano()


play_instrument(guitar)
play_instrument(piano)

# %%
# Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.

class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b


sum_result = MathOperations.add_numbers(10, 5)
print("Sum:", sum_result)


difference = MathOperations.subtract_numbers(10, 5)
print("Difference:", difference)

# %%
#   Implement a class Person with a class method to count the total number of persons created

class Person:
    count = 0

    def __init__(self, name):
        self.name = name
        Person.count += 1

    @classmethod
    def total_persons(cls):
        return f"Total persons created: {cls.count}"


p1 = Person("Alice")
p2 = Person("Bob")
p3 = Person("Charlie")


print(Person.total_persons())

# %%
#   Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".

class Fraction:
    def __init__(self, numerator, denominator):
        if denominator == 0:
            raise ValueError("Denominator cannot be zero")
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"


frac1 = Fraction(3, 4)
frac2 = Fraction(5, 8)


print(frac1)
print(frac2)

# %%
# Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.

class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y


    def __add__(self, other):
        if isinstance(other, Vector):
            return Vector(self.x + other.x, self.y + other.y)
        else:
            raise TypeError("Operand must be an instance of Vector")


    def __str__(self):
        return f"({self.x}, {self.y})"


v1 = Vector(2, 3)
v2 = Vector(4, 5)


v3 = v1 + v2


print(v3)

# %%
#  Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

person1 = Person("Alice", 30)


person1.greet()

# %%
#  Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.

class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        return sum(self.grades) / len(self.grades) if self.grades else 0

student1 = Student("John", [85, 90, 88, 92, 78])


avg = student1.average_grade()
print(f"Average grade of {student1.name}: {avg:.2f}")

# %%
#  Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.

class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

rectangle1 = Rectangle()

rectangle1.set_dimensions(5, 4)

print(f"Area of the rectangle: {rectangle1.area()}")

# %%
# Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.

class Employee:
    def __init__(self, name, hours_worked, hourly_rate):
        self.name = name
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate


class Manager(Employee):
    def __init__(self, name, hours_worked, hourly_rate, bonus):
        super().__init__(name, hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        base_salary = super().calculate_salary()
        return base_salary + self.bonus


employee1 = Employee("John", 40, 20)
manager1 = Manager("Alice", 40, 25, 500)


print(f"Employee Salary: ${employee1.calculate_salary()}")
print(f"Manager Salary: ${manager1.calculate_salary()}")

# %%
# Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.

class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

product1 = Product("Laptop", 1000, 3)


print(f"Total price of {product1.name}: ${product1.total_price()}")

# %%
# Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.

from abc import ABC, abstractmethod


class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass


class Cow(Animal):
    def sound(self):
        return "Moo"


class Sheep(Animal):
    def sound(self):
        return "Baa"


cow = Cow()
sheep = Sheep()


print(f"Cow sound: {cow.sound()}")
print(f"Sheep sound: {sheep.sound()}")

# %%
# Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.

class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"Title: {self.title}\nAuthor: {self.author}\nYear Published: {self.year_published}"


book1 = Book("To Kill a Mockingbird", "Harper Lee", 1960)


print(book1.get_book_info())

# %%
#  Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price


class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms


mansion1 = Mansion("123 Luxury Lane", 5000000, 10)


print(f"Address: {mansion1.address}")
print(f"Price: ${mansion1.price}")
print(f"Number of Rooms: {mansion1.number_of_rooms}")
